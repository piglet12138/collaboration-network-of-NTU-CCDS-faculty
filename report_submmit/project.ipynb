# %%
from preprocessing import *
from faculty import *

# %% [markdown]
# ## All data preparation,download the XML file from DBLP

# %%
# file = "Faculty.csv"
# download_dblp_xml(file)
# add_pid_to_faculty_csv("Faculty.csv")
# generate_raw_data()
# generate_network_links()

# %% [markdown]
# ## Network Visualization

# %%
networks = build_collaboration_networks('main_authors_collaborations.csv')
# print_network_info(networks)
# analyze_specific_year(networks, 2020)
# visualize_year_network(networks, 2025)
# visualize_network_evolution(networks, [2009, 2010, 2011])
# visualize_years_network_grid(networks, 2001, 2025)
create_network_dashboard(networks)
# Out:
# VBox(children=(Output(), HBox(children=(SelectionSlider(continuous_update=False, description='year:', index=38…

# %% [markdown]
# ## Question 1

# %%
get_network_statistics(year=2025)
compare_with_random_network(year=2025)
# Out:
# Collaboration Network Statistics:
# Number of nodes: 109
# Number of edges: 329
# Average degree: 6.04
# Clustering coefficient: 0.2677
# Average path length: 2.6690
#
# Generating comparable random network...
#
# Random Graph Statistics:
# Number of nodes: 109
# Number of edges: 329
# Average degree: 6.04
# Clustering coefficient: 0.0642
#
# Comparison ratios (real/random):
# Clustering coefficient ratio: 4.17x
# Number of nodes: 109
# Number of edges: 329
# Average degree: 6.04
# Clustering coefficient: 0.2677
# {'num_nodes': 109,
#  'num_edges': 329,
#  'avg_degree': 6.036697247706422,
#  'clustering_coefficient': 0.2677481469007185}

# %% [markdown]
# ## Question 2

# %%
visualize_statistics_change()

# %% [markdown]
# ## Question 3-5

# %%
analyze_and_visualize_collaboration(year = 2025, attribute_name="position", min_faculty=3)
analyze_and_visualize_collaboration(year = 2025, attribute_name="management", min_faculty=3)
analyze_and_visualize_collaboration(year = 2025, attribute_name="area", min_faculty=3)
# Out:
# Distribution of faculty by position:
# Associate Professor: 43 faculty
# Assistant Professor: 35 faculty
# Professor: 18 faculty
# Lecturer: 8 faculty
# Senior Lecturer: 5 faculty
# Distribution of faculty by management:
# N: 100 faculty
# Y: 9 faculty
# Distribution of faculty by area:
# AI/ML: 28 faculty
# Computer Architecture: 13 faculty
# Computer Vision: 12 faculty
# Computer Networks: 10 faculty
# Software Engg: 9 faculty
# Cyber Security: 7 faculty
# Distributed Systems: 7 faculty
# HCI: 5 faculty
# Computer Graphics: 4 faculty
# Data Management: 3 faculty
# Data Mining: 3 faculty
# Multimedia: 3 faculty
# Bioinformatics: 3 faculty
# Information Retrieval: 2 faculty
# {'node_attributes': {'15/3108': 'Computer Graphics',
#   's/SeahHockSoon': 'Computer Graphics',
#   '163/6518': 'Computer Architecture',
#   '64/4136': 'AI/ML',
#   '51/3710-3': 'Software Engg',
#   '81/8329': 'AI/ML',
#   '65/3225': 'Information Retrieval',
#   '99/4535': 'Computer Architecture',
#   '76/440': 'Computer Networks',
#   '80/7421': 'AI/ML',
#   '10/1993': 'Cyber Security',
#   '95/7006': 'AI/ML',
#   '73/1708': 'Computer Architecture',
#   '41/8030': 'Cyber Security',
#   '84/2408': 'HCI',
#   '23/1694': 'Computer Architecture',
#   'd/AnwitamanDatta': 'Distributed Systems',
#   '78/5155': 'Information Retrieval',
#   'l/BuSungLee': 'Computer Networks',
#   '84/6889-2': 'AI/ML',
#   'n/WeeKeongNg': 'Cyber Security',
#   '67/2933': 'Data Management',
#   '117/5965': 'Data Mining',
#   '58/10813-1': 'Data Mining',
#   '52/910': 'Computer Networks',
#   '33/3180': 'Data Mining',
#   'b/SSBhowmick': 'Data Management',
#   '90/9499': 'Computer Vision',
#   '66/549': 'Computer Networks',
#   '30/6609': 'Computer Networks',
#   '70/1211': 'AI/ML',
#   '42/6178-1': 'AI/ML',
#   '12/9925': 'AI/ML',
#   '93/4009': 'AI/ML',
#   'm/ChunyanMiao': 'AI/ML',
#   '80/5412': 'AI/ML',
#   '46/3391': 'AI/ML',
#   '03/1554-1': 'AI/ML',
#   '35/1096-1': 'AI/ML',
#   '83/6096': 'Computer Vision',
#   '126/4778': 'Computer Vision',
#   '29/3808': 'Computer Vision',
#   '09/5452': 'Computer Graphics',
#   '79/8116': 'Computer Vision',
#   '42/2718': 'Computer Vision',
#   '01/5855': 'Computer Vision',
#   '62/2078': 'AI/ML',
#   '33/885': 'Multimedia',
#   '14/3737': 'Multimedia',
#   '05/2952': 'Multimedia',
#   '95/3115': 'Computer Vision',
#   '83/3179': 'Distributed Systems',
#   '23/2460': 'Distributed Systems',
#   's/CZSun': 'HCI',
#   '61/3119': 'Distributed Systems',
#   '160/7116': 'Data Management',
#   '80/2106': 'Computer Networks',
#   '04/3030': 'Computer Networks',
#   'q/HiokChaiQuek': 'AI/ML',
#   '38/3641': 'AI/ML',
#   'c/ChngEngSiong': 'AI/ML',
#   '00/4516-3': 'AI/ML',
#   '97/6922': 'HCI',
#   '92/748-7': 'Cyber Security',
#   '165/2801': 'Software Engg',
#   '69/8028': 'Computer Architecture',
#   '191/7824': 'Distributed Systems',
#   '63/6663': 'Computer Architecture',
#   '249/5315': 'Distributed Systems',
#   '42/2501-1': 'Computer Networks',
#   '47/2026-7': 'Computer Networks',
#   '91/665': 'Bioinformatics',
#   '35/6803': 'AI/ML',
#   '242/0323': 'Cyber Security',
#   '32/228': 'Bioinformatics',
#   'h/YingHe1': 'Computer Graphics',
#   '00/5179': 'Computer Architecture',
#   '75/198-1': 'Distributed Systems',
#   '87/4982-1': 'Computer Networks',
#   '70/1211-1': 'AI/ML',
#   '07/3111': 'AI/ML',
#   '16/3792': 'Computer Vision',
#   'o/CHLukeOng': 'Software Engg',
#   '74/1907': 'Computer Architecture',
#   '55/9613': 'AI/ML',
#   '224/9431': 'Computer Architecture',
#   'a/QianhuiAltheaLiang': 'AI/ML',
#   '75/2611-2': 'Bioinformatics',
#   '78/6459': 'Computer Vision',
#   '62/7948': 'AI/ML',
#   '55/4730-1': 'Software Engg',
#   '59/871-8': 'Software Engg',
#   '24/914': 'Computer Architecture',
#   '32/3735': 'Computer Vision',
#   '11/9550': 'Computer Vision',
#   '211/7940': 'AI/ML',
#   '95/378': 'AI/ML',
#   'w/MelanieWeis': 'Computer Architecture',
#   '74/5309': 'Computer Architecture',
#   '59/4829': 'AI/ML',
#   '220/7546': 'HCI',
#   '73/4788': 'Computer Architecture',
#   '77/7902': 'Cyber Security',
#   '93/7359': 'Software Engg',
#   '36/9306': 'Cyber Security',
#   '122/9933': 'Software Engg',
#   '251/9647': 'Software Engg',
#   '84/2694-21': 'HCI',
#   '59/871-2': 'Software Engg'},
#  'attribute_data': {'Computer Graphics': ['15/3108',
#    's/SeahHockSoon',
#    '09/5452',
#    'h/YingHe1'],
#   'Computer Architecture': ['163/6518',
#    '99/4535',
#    '73/1708',
#    '23/1694',
#    '69/8028',
#    '63/6663',
#    '00/5179',
#    '74/1907',
#    '224/9431',
#    '24/914',
#    'w/MelanieWeis',
#    '74/5309',
#    '73/4788'],
#   'AI/ML': ['64/4136',
#    '81/8329',
#    '80/7421',
#    '95/7006',
#    '84/6889-2',
#    '70/1211',
#    '42/6178-1',
#    '12/9925',
#    '93/4009',
#    'm/ChunyanMiao',
#    '80/5412',
#    '46/3391',
#    '03/1554-1',
#    '35/1096-1',
#    '62/2078',
#    'q/HiokChaiQuek',
#    '38/3641',
#    'c/ChngEngSiong',
#    '00/4516-3',
#    '35/6803',
#    '70/1211-1',
#    '07/3111',
#    '55/9613',
#    'a/QianhuiAltheaLiang',
#    '62/7948',
#    '211/7940',
#    '95/378',
#    '59/4829'],
#   'Software Engg': ['51/3710-3',
#    '165/2801',
#    'o/CHLukeOng',
#    '55/4730-1',
#    '59/871-8',
#    '93/7359',
#    '122/9933',
#    '251/9647',
#    '59/871-2'],
#   'Information Retrieval': ['65/3225', '78/5155'],
#   'Computer Networks': ['76/440',
#    'l/BuSungLee',
#    '52/910',
#    '66/549',
#    '30/6609',
#    '80/2106',
#    '04/3030',
#    '42/2501-1',
#    '47/2026-7',
#    '87/4982-1'],
#   'Cyber Security': ['10/1993',
#    '41/8030',
#    'n/WeeKeongNg',
#    '92/748-7',
#    '242/0323',
#    '77/7902',
#    '36/9306'],
#   'HCI': ['84/2408', 's/CZSun', '97/6922', '220/7546', '84/2694-21'],
#   'Distributed Systems': ['d/AnwitamanDatta',
#    '83/3179',
#    '23/2460',
#    '61/3119',
#    '191/7824',
#    '249/5315',
#    '75/198-1'],
#   'Data Management': ['67/2933', 'b/SSBhowmick', '160/7116'],
#   'Data Mining': ['117/5965', '58/10813-1', '33/3180'],
#   'Computer Vision': ['90/9499',
#    '83/6096',
#    '126/4778',
#    '29/3808',
#    '79/8116',
#    '42/2718',
#    '01/5855',
#    '95/3115',
#    '16/3792',
#    '78/6459',
#    '32/3735',
#    '11/9550'],
#   'Multimedia': ['33/885', '14/3737', '05/2952'],
#   'Bioinformatics': ['91/665', '32/228', '75/2611-2']},
#  'attribute_counts': {'Computer Graphics': 4,
#   'Computer Architecture': 13,
#   'AI/ML': 28,
#   'Software Engg': 9,
#   'Information Retrieval': 2,
#   'Computer Networks': 10,
#   'Cyber Security': 7,
#   'HCI': 5,
#   'Distributed Systems': 7,
#   'Data Management': 3,
#   'Data Mining': 3,
#   'Computer Vision': 12,
#   'Multimedia': 3,
#   'Bioinformatics': 3},
#  'attribute_collaborations': defaultdict(<function faculty.analyze_faculty_collaboration.<locals>.<lambda>()>,
#              {'Computer Graphics': {'internal': 4.0,
#                'external': 9.0,
#                'nodes': 4},
#               'Computer Architecture': {'internal': 5.0,
#                'external': 15.5,
#                'nodes': 13},
#               'AI/ML': {'internal': 69.0, 'external': 51.5, 'nodes': 28},
#               'Software Engg': {'internal': 4.0, 'external': 8.0, 'nodes': 9},
#               'Information Retrieval': {'internal': 0,
#                'external': 11.5,
#                'nodes': 2},
#               'Computer Networks': {'internal': 11.0,
#                'external': 31.0,
#                'nodes': 10},
#               'Cyber Security': {'internal': 3.0,
#                'external': 11.5,
#                'nodes': 7},
#               'HCI': {'internal': 0, 'external': 7.0, 'nodes': 5},
#               'Distributed Systems': {'internal': 2.0,
#                'external': 10.0,
#                'nodes': 7},
#               'Data Management': {'internal': 1.0,
#                'external': 7.0,
#                'nodes': 3},
#               'Data Mining': {'internal': 3.0, 'external': 9.5, 'nodes': 3},
#               'Computer Vision': {'internal': 7.0,
#                'external': 26.5,
#                'nodes': 12},
#               'Multimedia': {'internal': 2.0, 'external': 16.0, 'nodes': 3},
#               'Bioinformatics': {'internal': 0, 'external': 4.0, 'nodes': 3}}),
#  'collab_df':                        internal  external  nodes  avg_internal  avg_external  \
#  Multimedia                  2.0      16.0      3      0.666667      5.333333
#  Information Retrieval       0.0      11.5      2      0.000000      5.750000
#  AI/ML                      69.0      51.5     28      2.464286      1.839286
#  Computer Networks          11.0      31.0     10      1.100000      3.100000
#  Data Mining                 3.0       9.5      3      1.000000      3.166667
#  Computer Graphics           4.0       9.0      4      1.000000      2.250000
#  Computer Vision             7.0      26.5     12      0.583333      2.208333
#  Data Management             1.0       7.0      3      0.333333      2.333333
#  Cyber Security              3.0      11.5      7      0.428571      1.642857
#  Distributed Systems         2.0      10.0      7      0.285714      1.428571
#  Computer Architecture       5.0      15.5     13      0.384615      1.192308
#  HCI                         0.0       7.0      5      0.000000      1.400000
#  Software Engg               4.0       8.0      9      0.444444      0.888889
#  Bioinformatics              0.0       4.0      3      0.000000      1.333333
#
#                         total_collaborations  avg_total  internal_ratio
#  Multimedia                             18.0   6.000000        0.111111
#  Information Retrieval                  11.5   5.750000        0.000000
#  AI/ML                                 120.5   4.303571        0.572614
#  Computer Networks                      42.0   4.200000        0.261905
#  Data Mining                            12.5   4.166667        0.240000
#  Computer Graphics                      13.0   3.250000        0.307692
#  Computer Vision                        33.5   2.791667        0.208955
#  Data Management                         8.0   2.666667        0.125000
#  Cyber Security                         14.5   2.071429        0.206897
#  Distributed Systems                    12.0   1.714286        0.166667
#  Computer Architecture                  20.5   1.576923        0.243902
#  HCI                                     7.0   1.400000        0.000000
#  Software Engg                          12.0   1.333333        0.333333
#  Bioinformatics                          4.0   1.333333        0.000000  ,
#  'cross_attribute_edges': [('Computer Graphics', 'Computer Architecture'),
#   ('Computer Graphics', 'Distributed Systems'),
#   ('Computer Graphics', 'Data Mining'),
#   ('Computer Graphics', 'Bioinformatics'),
#   ('Computer Graphics', 'Multimedia'),
#   ('Computer Graphics', 'HCI'),
#   ('Computer Graphics', 'Computer Vision'),
#   ('Computer Graphics', 'AI/ML'),
#   ('Computer Graphics', 'Computer Architecture'),
#   ('Computer Architecture', 'AI/ML'),
#   ('Computer Architecture', 'Software Engg'),
#   ('Computer Architecture', 'AI/ML'),
#   ('Computer Architecture', 'Information Retrieval'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Distributed Systems'),
#   ('AI/ML', 'Data Mining'),
#   ('AI/ML', 'Bioinformatics'),
#   ('AI/ML', 'Computer Networks'),
#   ('AI/ML', 'Computer Architecture'),
#   ('AI/ML', 'Software Engg'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Data Management'),
#   ('AI/ML', 'Computer Graphics'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Multimedia'),
#   ('AI/ML', 'Cyber Security'),
#   ('Software Engg', 'Distributed Systems'),
#   ('Software Engg', 'AI/ML'),
#   ('Software Engg', 'Cyber Security'),
#   ('Software Engg', 'Multimedia'),
#   ('Software Engg', 'AI/ML'),
#   ('Software Engg', 'AI/ML'),
#   ('Software Engg', 'Multimedia'),
#   ('Software Engg', 'AI/ML'),
#   ('Software Engg', 'AI/ML'),
#   ('Software Engg', 'AI/ML'),
#   ('Software Engg', 'HCI'),
#   ('AI/ML', 'Information Retrieval'),
#   ('AI/ML', 'Computer Vision'),
#   ('Information Retrieval', 'Data Mining'),
#   ('Information Retrieval', 'Computer Networks'),
#   ('Information Retrieval', 'Computer Networks'),
#   ('Information Retrieval', 'Computer Networks'),
#   ('Information Retrieval', 'Computer Networks'),
#   ('Computer Architecture', 'Computer Networks'),
#   ('Computer Architecture', 'AI/ML'),
#   ('Computer Architecture', 'Cyber Security'),
#   ('Computer Architecture', 'AI/ML'),
#   ('Computer Architecture', 'Cyber Security'),
#   ('Computer Architecture', 'HCI'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Cyber Security'),
#   ('Computer Networks', 'Multimedia'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Distributed Systems'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'AI/ML'),
#   ('AI/ML', 'Bioinformatics'),
#   ('AI/ML', 'Information Retrieval'),
#   ('Cyber Security', 'Computer Networks'),
#   ('Cyber Security', 'Computer Vision'),
#   ('Cyber Security', 'Computer Networks'),
#   ('Cyber Security', 'Software Engg'),
#   ('Cyber Security', 'Computer Vision'),
#   ('Cyber Security', 'Information Retrieval'),
#   ('Cyber Security', 'AI/ML'),
#   ('AI/ML', 'HCI'),
#   ('AI/ML', 'Bioinformatics'),
#   ('AI/ML', 'Computer Networks'),
#   ('AI/ML', 'Computer Vision'),
#   ('Computer Architecture', 'Computer Vision'),
#   ('Cyber Security', 'Data Management'),
#   ('HCI', 'Cyber Security'),
#   ('HCI', 'Bioinformatics'),
#   ('Computer Architecture', 'HCI'),
#   ('Computer Architecture', 'Multimedia'),
#   ('Distributed Systems', 'Information Retrieval'),
#   ('Distributed Systems', 'Computer Networks'),
#   ('Distributed Systems', 'AI/ML'),
#   ('Distributed Systems', 'Cyber Security'),
#   ('Information Retrieval', 'AI/ML'),
#   ('Information Retrieval', 'Data Mining'),
#   ('Information Retrieval', 'AI/ML'),
#   ('Information Retrieval', 'Computer Networks'),
#   ('Information Retrieval', 'Data Mining'),
#   ('Information Retrieval', 'Computer Networks'),
#   ('Information Retrieval', 'AI/ML'),
#   ('Information Retrieval', 'Cyber Security'),
#   ('Information Retrieval', 'AI/ML'),
#   ('Information Retrieval', 'Data Management'),
#   ('Information Retrieval', 'AI/ML'),
#   ('Information Retrieval', 'Distributed Systems'),
#   ('Information Retrieval', 'AI/ML'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'Distributed Systems'),
#   ('Computer Networks', 'Multimedia'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'Distributed Systems'),
#   ('Computer Networks', 'Distributed Systems'),
#   ('Computer Networks', 'Computer Architecture'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Computer Architecture'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Multimedia'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'AI/ML'),
#   ('AI/ML', 'Data Mining'),
#   ('AI/ML', 'Cyber Security'),
#   ('Cyber Security', 'Multimedia'),
#   ('Cyber Security', 'Multimedia'),
#   ('Cyber Security', 'Data Management'),
#   ('Data Management', 'Data Mining'),
#   ('Data Management', 'Data Mining'),
#   ('Data Management', 'Computer Networks'),
#   ('Data Management', 'Data Mining'),
#   ('Data Mining', 'Computer Vision'),
#   ('Data Mining', 'AI/ML'),
#   ('Data Mining', 'Computer Vision'),
#   ('Data Mining', 'AI/ML'),
#   ('Data Mining', 'AI/ML'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'Multimedia'),
#   ('Computer Networks', 'AI/ML'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'Computer Architecture'),
#   ('Computer Networks', 'Distributed Systems'),
#   ('Computer Networks', 'Computer Architecture'),
#   ('Computer Networks', 'AI/ML'),
#   ('Data Mining', 'AI/ML'),
#   ('Data Mining', 'Cyber Security'),
#   ('Data Mining', 'AI/ML'),
#   ('Data Mining', 'Data Management'),
#   ('Data Mining', 'AI/ML'),
#   ('Data Management', 'Multimedia'),
#   ('Data Management', 'AI/ML'),
#   ('Data Management', 'AI/ML'),
#   ('Data Management', 'Computer Networks'),
#   ('Computer Networks', 'Computer Vision'),
#   ('Computer Networks', 'Multimedia'),
#   ('Computer Networks', 'Computer Architecture'),
#   ('AI/ML', 'Computer Graphics'),
#   ('AI/ML', 'Distributed Systems'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Distributed Systems'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Multimedia'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Computer Networks'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Multimedia'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Cyber Security'),
#   ('AI/ML', 'Multimedia'),
#   ('AI/ML', 'Software Engg'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Distributed Systems'),
#   ('AI/ML', 'Computer Vision'),
#   ('AI/ML', 'Computer Architecture'),
#   ('AI/ML', 'Distributed Systems'),
#   ('AI/ML', 'Multimedia'),
#   ('AI/ML', 'Computer Networks'),
#   ('Computer Vision', 'Computer Graphics'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'Multimedia'),
#   ('Computer Vision', 'Multimedia'),
#   ('Computer Vision', 'Multimedia'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'Multimedia'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'Computer Architecture'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'Data Management'),
#   ('Computer Vision', 'Computer Graphics'),
#   ('Computer Vision', 'Multimedia'),
#   ('Computer Graphics', 'Multimedia'),
#   ('Computer Graphics', 'Computer Vision'),
#   ('Computer Vision', 'Computer Architecture'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'Multimedia'),
#   ('Computer Vision', 'AI/ML'),
#   ('AI/ML', 'Computer Networks'),
#   ('Multimedia', 'Computer Networks'),
#   ('Multimedia', 'Bioinformatics'),
#   ('Multimedia', 'Software Engg'),
#   ('Multimedia', 'Computer Networks'),
#   ('Multimedia', 'Computer Networks'),
#   ('Multimedia', 'Computer Vision'),
#   ('Multimedia', 'AI/ML'),
#   ('Multimedia', 'AI/ML'),
#   ('Computer Vision', 'Computer Networks'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'Computer Architecture'),
#   ('Computer Vision', 'AI/ML'),
#   ('Computer Vision', 'AI/ML'),
#   ('Distributed Systems', 'HCI'),
#   ('HCI', 'Computer Networks'),
#   ('AI/ML', 'Computer Architecture'),
#   ('AI/ML', 'HCI'),
#   ('AI/ML', 'HCI'),
#   ('HCI', 'Computer Architecture'),
#   ('HCI', 'Cyber Security'),
#   ('HCI', 'Computer Architecture'),
#   ('Computer Networks', 'Computer Graphics'),
#   ('Computer Networks', 'Distributed Systems'),
#   ('Computer Networks', 'Computer Architecture'),
#   ('Bioinformatics', 'Computer Graphics'),
#   ('Computer Graphics', 'Computer Architecture'),
#   ('Distributed Systems', 'Computer Networks'),
#   ('Computer Architecture', 'AI/ML'),
#   ('Bioinformatics', 'Computer Vision')],
#  'cross_collab_counts': Counter({('AI/ML', 'Computer Vision'): 15,
#           ('Computer Networks', 'AI/ML'): 13,
#           ('Computer Vision', 'AI/ML'): 9,
#           ('Computer Networks', 'Computer Vision'): 7,
#           ('Software Engg', 'AI/ML'): 6,
#           ('Information Retrieval', 'Computer Networks'): 6,
#           ('Computer Networks', 'Distributed Systems'): 6,
#           ('Information Retrieval', 'AI/ML'): 6,
#           ('Computer Networks', 'Computer Architecture'): 6,
#           ('Data Mining', 'AI/ML'): 6,
#           ('Computer Vision', 'Multimedia'): 6,
#           ('Computer Architecture', 'AI/ML'): 5,
#           ('AI/ML', 'Distributed Systems'): 5,
#           ('AI/ML', 'Computer Networks'): 5,
#           ('AI/ML', 'Multimedia'): 5,
#           ('Computer Networks', 'Multimedia'): 5,
#           ('Computer Graphics', 'Computer Architecture'): 3,
#           ('AI/ML', 'Bioinformatics'): 3,
#           ('AI/ML', 'Computer Architecture'): 3,
#           ('AI/ML', 'Cyber Security'): 3,
#           ('Information Retrieval', 'Data Mining'): 3,
#           ('AI/ML', 'HCI'): 3,
#           ('Data Management', 'Data Mining'): 3,
#           ('Computer Vision', 'Computer Architecture'): 3,
#           ('Multimedia', 'Computer Networks'): 3,
#           ('Computer Graphics', 'Multimedia'): 2,
#           ('Computer Graphics', 'Computer Vision'): 2,
#           ('AI/ML', 'Data Mining'): 2,
#           ('AI/ML', 'Software Engg'): 2,
#           ('AI/ML', 'Computer Graphics'): 2,
#           ('Software Engg', 'Multimedia'): 2,
#           ('AI/ML', 'Information Retrieval'): 2,
#           ('Computer Architecture', 'Cyber Security'): 2,
#           ('Computer Architecture', 'HCI'): 2,
#           ('Cyber Security', 'Computer Networks'): 2,
#           ('Cyber Security', 'Computer Vision'): 2,
#           ('Cyber Security', 'Data Management'): 2,
#           ('HCI', 'Cyber Security'): 2,
#           ('Distributed Systems', 'Computer Networks'): 2,
#           ('Cyber Security', 'Multimedia'): 2,
#           ('Data Management', 'Computer Networks'): 2,
#           ('Data Mining', 'Computer Vision'): 2,
#           ('Data Management', 'AI/ML'): 2,
#           ('Computer Vision', 'Computer Graphics'): 2,
#           ('Multimedia', 'AI/ML'): 2,
#           ('HCI', 'Computer Architecture'): 2,
#           ('Computer Graphics', 'Distributed Systems'): 1,
#           ('Computer Graphics', 'Data Mining'): 1,
#           ('Computer Graphics', 'Bioinformatics'): 1,
#           ('Computer Graphics', 'HCI'): 1,
#           ('Computer Graphics', 'AI/ML'): 1,
#           ('Computer Architecture', 'Software Engg'): 1,
#           ('Computer Architecture', 'Information Retrieval'): 1,
#           ('AI/ML', 'Data Management'): 1,
#           ('Software Engg', 'Distributed Systems'): 1,
#           ('Software Engg', 'Cyber Security'): 1,
#           ('Software Engg', 'HCI'): 1,
#           ('Computer Architecture', 'Computer Networks'): 1,
#           ('Computer Networks', 'Cyber Security'): 1,
#           ('Cyber Security', 'Software Engg'): 1,
#           ('Cyber Security', 'Information Retrieval'): 1,
#           ('Cyber Security', 'AI/ML'): 1,
#           ('Computer Architecture', 'Computer Vision'): 1,
#           ('HCI', 'Bioinformatics'): 1,
#           ('Computer Architecture', 'Multimedia'): 1,
#           ('Distributed Systems', 'Information Retrieval'): 1,
#           ('Distributed Systems', 'AI/ML'): 1,
#           ('Distributed Systems', 'Cyber Security'): 1,
#           ('Information Retrieval', 'Cyber Security'): 1,
#           ('Information Retrieval', 'Data Management'): 1,
#           ('Information Retrieval', 'Distributed Systems'): 1,
#           ('Data Mining', 'Cyber Security'): 1,
#           ('Data Mining', 'Data Management'): 1,
#           ('Data Management', 'Multimedia'): 1,
#           ('Computer Vision', 'Data Management'): 1,
#           ('Multimedia', 'Bioinformatics'): 1,
#           ('Multimedia', 'Software Engg'): 1,
#           ('Multimedia', 'Computer Vision'): 1,
#           ('Computer Vision', 'Computer Networks'): 1,
#           ('Distributed Systems', 'HCI'): 1,
#           ('HCI', 'Computer Networks'): 1,
#           ('Computer Networks', 'Computer Graphics'): 1,
#           ('Bioinformatics', 'Computer Graphics'): 1,
#           ('Bioinformatics', 'Computer Vision'): 1}),
#  'attribute_matrix':                        AI/ML  Bioinformatics  Computer Architecture  \
#  AI/ML                      0               3                      8
#  Bioinformatics             3               0                      0
#  Computer Architecture      8               0                      0
#  Computer Graphics          3               2                      3
#  Computer Networks         18               0                      7
#  Computer Vision           24               1                      4
#  Cyber Security             4               0                      2
#  Data Management            3               0                      0
#  Data Mining                8               0                      0
#  Distributed Systems        6               0                      0
#  HCI                        3               1                      4
#  Information Retrieval      8               0                      1
#  Multimedia                 7               1                      1
#  Software Engg              8               0                      1
#
#                         Computer Graphics  Computer Networks  Computer Vision  \
#  AI/ML                                  3                 18               24
#  Bioinformatics                         2                  0                1
#  Computer Architecture                  3                  7                4
#  Computer Graphics                      0                  1                4
#  Computer Networks                      1                  0                8
#  Computer Vision                        4                  8                0
#  Cyber Security                         0                  3                2
#  Data Management                        0                  2                1
#  Data Mining                            1                  0                2
#  Distributed Systems                    1                  8                0
#  HCI                                    1                  1                0
#  Information Retrieval                  0                  6                0
#  Multimedia                             2                  8                7
#  Software Engg                          0                  0                0
#
#                         Cyber Security  Data Management  Data Mining  \
#  AI/ML                               4                3            8
#  Bioinformatics                      0                0            0
#  Computer Architecture               2                0            0
#  Computer Graphics                   0                0            1
#  Computer Networks                   3                2            0
#  Computer Vision                     2                1            2
#  Cyber Security                      0                2            1
#  Data Management                     2                0            4
#  Data Mining                         1                4            0
#  Distributed Systems                 1                0            0
#  HCI                                 2                0            0
#  Information Retrieval               2                1            3
#  Multimedia                          2                1            0
#  Software Engg                       2                0            0
#
#                         Distributed Systems  HCI  Information Retrieval  \
#  AI/ML                                    6    3                      8
#  Bioinformatics                           0    1                      0
#  Computer Architecture                    0    4                      1
#  Computer Graphics                        1    1                      0
#  Computer Networks                        8    1                      6
#  Computer Vision                          0    0                      0
#  Cyber Security                           1    2                      2
#  Data Management                          0    0                      1
#  Data Mining                              0    0                      3
#  Distributed Systems                      0    1                      2
#  HCI                                      1    0                      0
#  Information Retrieval                    2    0                      0
#  Multimedia                               0    0                      0
#  Software Engg                            1    1                      0
#
#                         Multimedia  Software Engg
#  AI/ML                           7              8
#  Bioinformatics                  1              0
#  Computer Architecture           1              1
#  Computer Graphics               2              0
#  Computer Networks               8              0
#  Computer Vision                 7              0
#  Cyber Security                  2              2
#  Data Management                 1              0
#  Data Mining                     0              0
#  Distributed Systems             0              1
#  HCI                             0              1
#  Information Retrieval           0              0
#  Multimedia                      0              3
#  Software Engg                   3              0  ,
#  'unique_attributes': ['AI/ML',
#   'Bioinformatics',
#   'Computer Architecture',
#   'Computer Graphics',
#   'Computer Networks',
#   'Computer Vision',
#   'Cyber Security',
#   'Data Management',
#   'Data Mining',
#   'Distributed Systems',
#   'HCI',
#   'Information Retrieval',
#   'Multimedia',
#   'Software Engg']}

# %% [markdown]
# ## Q7

# %%
folder_path = r"faculty_data" #subsitute with relative path
output_json_path = r"papers_by_key.json" #relative path
input_json = r"papers_by_key.json"
output_json = r"papers_by_key_cleaned.json"

process_faculty_folder(folder_path, output_json_path)
deduplicate_paper_data(input_json, output_json)
page_rank_network()
new_1000_network()
overall_info()
network_degree_plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       3 input_json = r"papers_by_key.json"
#       4 output_json = r"papers_by_key_cleaned.json"
# ----> 6 process_faculty_folder(folder_path, output_json_path)
#       7 deduplicate_paper_data(input_json, output_json)
#       8 page_rank_network()
#
# File ~\Documents\GitHub\collaboration-network-of-NTU-CCDS-faculty-\report_submmit\preprocessing.py:877, in process_faculty_folder(folder_path, output_path)
#     875     if filename.endswith(".xml"):
#     876         xml_path = os.path.join(folder_path, filename)
# --> 877         papers_by_key.update(extract_paper_data(xml_path))
#     879 with open(output_path, "w", encoding="utf-8") as f:
#     880     json.dump(papers_by_key, f, indent=2, ensure_ascii=False)
#
# TypeError: 'NoneType' object is not iterable
